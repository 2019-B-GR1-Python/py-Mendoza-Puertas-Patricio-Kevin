# %%
def menu1():  
    print("===========================EPN===========================")
    print("==========================Python=========================")
    print("=============Registro Estudiante y universidad===========")
    print("1. Estudiante")
    print("2. Universidad")
    opcion_menu1 = input("Escoger una opcion: ")
    
    
    return opcion_menu1

def menu2():
    print("===========================================================")
    print("1. Ingresar")
    print("2. Consultar")
    print("3. Actualizar")
    print("4. Eliminar")
    print("===========================================================")
    opcion_menu2 = input("Escoger una opcion: ")
   
    return opcion_menu2

principal = menu1()
crud = menu2()

print(principal,crud)
def buscar(buscar_id, principal):
    if (principal == "1"):
        try:
            path = "./estudiante.txt"
            archivo_abierto = open(path)
            archivo = archivo_abierto.readlines()
                   
            for linea in archivo:
                id_buscado = linea.find(buscar_id)
                
                if (id_buscado == 0):
                    print(linea)
            
            archivo_abierto.close()
        except Exception as error:
            print("Error")
    
    else:
        try:
            path = "./universidad.txt"
            archivo_abierto = open(path)
            archivo = archivo_abierto.readlines()
            
            for linea in archivo:
                id_buscado = linea.find(buscar_id)
            
                if (id_buscado == 0):
                    print(linea)
            
            archivo_abierto.close()
        except Exception as error:
            print("Error")
    
    return archivo_abierto



def insertar():
    
    if (principal == "1"):
        print("\n  Ingrese la informacion del estudiante\n")
        id = input("  id: ")
        nombre = input("  Nombre: ")
        apellido = input("  Apellido: ")
        edad = input("  Edad: ")
        try:
            path = "./estudiante.txt"
            archivo_abierto = open(path, mode = "a")
            archivo_abierto.write(f"{id} ,{nombre}, {apellido} ,{edad}\n")            
            archivo_abierto.close()
            print("\n Ingreso exitoso \n")
        except Exception as error:
            print("Error")
    
    else:
        print("\n  Ingrese la informacion de la universidad\n")
        id = input("  id: ")
        nombre = input("  Nombre: ")
        direccion = input("  Direccion: ")
        categoria = input("  Categoria: ")
        try:
            path = "./universidad.txt"
            archivo_abierto = open(path, mode = "a")
            archivo_abierto.write(f"{id} ,{nombre}, {direccion} ,{categoria}\n")            
            archivo_abierto.close()
            print("\n Ingreso exitoso \n")
        except Exception as error:
            print("Error")
    
    return archivo_abierto


def eliminar(eliminar_id, principal):
    if (principal == "1"):
        try:
            path = "./estudiante.txt"
            archivo_abierto = open(path, "r")
            archivo = archivo_abierto.readlines()
            
            archivo_abierto = open(path, "w")
                            
            for linea in archivo:
                id_encontrado = linea.find(id_a_eliminar)
                if (id_encontrado != 0):
                    archivo_abierto.write(linea)
                            
            archivo_abierto.close()
        except Exception as error:
            print("Error")
    
    else:
        try:
            path = "./universidad.txt"
            archivo_abierto = open(path, "r")
            archivo = archivo_abierto.readlines()
            
            archivo_abierto = open(path, "w")
                            
            for linea in archivo:
                id_buscado = linea.find(eliminar_id)
                if (id_buscado != 0):
                    archivo_abierto.write(linea)
            
            archivo_abierto.close()
        except Exception as error:
            print("Error")
    
    return archivo_abierto


def escribir_archivo(principal):
    if(principal == "1"):
        try:
            path = "./estudiante.txt"
            archivo_abierto = open(path)
            archivo = archivo_abierto.readlines()
        
            for linea in archivo:
                print(linea)
        
            archivo_abierto.close()
        except Exception as error:
            print("Error")
    
    else:
        try:
            path = "./universidad.txt"
            archivo_abierto = open(path)
            archivo = archivo_abierto.readlines()
        
            for linea in archivo:
                print(linea)
        
            archivo_abierto.close()
        except Exception as error:
            print("Error")

            
def actualizar():
    if (principal == "1"):
        try:
            print("\n  Ingrese la informacion del estudiante\n")
            id = input("  id: ")
            nombre = input("  Nombre: ")
            apellido = input("  Apellido: ")
            edad = input("  Edad: ")
            
            path = "./estudiante.txt"
            archivo_abierto = open(path, "r")
            archivo = archivo_abierto.readlines()
            archivo_abierto.close()
            
            archivo_abierto = open(path, "w")
            
            print(archivo)
                        
            for linea in archivo:
                id_buscado = linea.find(actualizar_id)
                if (id_buscado != 0):
                    archivo_abierto.write(linea)
                else:
                    archivo_abierto.write(actualizar_linea)               
            archivo_abierto.close()
        except Exception as error:
            print("Error")
    
    else:
        try:
            print("\n  Ingrese la informacion de la universidad\n")
            id = input("  id: ")
            nombre = input("  Nombre: ")
            direccion = input("  Direccion: ")
            categoria = input("  Categoria: ")
            
            path = "./universidad.txt"
            archivo_abierto = open(path, "r")
            archivo = archivo_abierto.readlines()
            archivo_abierto.close()
            
            archivo_abierto = open(path, "w")
            
            print(archivo)
                        
            for linea in archivo:
                id_buscado = linea.find(actualizar_id)
                if (id_buscado != 0):
                    archivo_abierto.write(linea)
                else:
                    archivo_abierto.write(linea_actualizada)
                                         
            archivo_abierto.close()
        except Exception as error:
            print("Error")
    
    return archivo_abierto            


if(crud == "1"):
    if(principal == "1"):
        insertar()
    
    else:
        insertar()
        
if (crud == "2"):
    escribir_archivo(principal)
    buscar_id = input("Ingrese el id: ")
    buscar(buscar_id, principal)
    
    
if (crud == "3"):
    escribir_archivo(principal)
    actualizar_id = input("Ingrese el id que quiere actualizar: ")
    actualizar()
        
if (crud == "4"):
    escribir_archivo(principal)
    eliminar_id = input("Introduzca el id que quiere eliminar: ")
    eliminar(eliminar_id, principal)
# Out:
# ===========================EPN===========================
# ==========================Python=========================
# =============Registro Estudiante y universidad===========
# 1. Estudiante
# 2. Universidad
# Escoger una opcion: 1
# ...
# 1. Ingresar
# 2. Consultar
# 3. Actualizar
# 4. Eliminar
# ...
# Escoger una opcion: 2
# 1 2
# 1 ,a, s ,12
#
# 2 ,ddfcdf, cfdsd ,15
#
# Ingrese el id: 1
# 1 ,a, s ,12
